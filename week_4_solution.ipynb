# %% [markdown]
# #  Homework 3
# ## MBIO612
# ### Gabrielle Martineau

# %% [markdown]
# ## Question 1: Write a function that manually computes the standard deviation

# %%
##Prep
#Set working directory
setwd("~/U_of_H/FALL_2021/MBIO612/Week_4")
library("tidyverse")
# Out:
# Warning message:
# "package 'tidyverse' was built under R version 3.6.3"-- Attaching packages --------------------------------------- tidyverse 1.3.1 --
# v ggplot2 3.3.5     v purrr   0.3.4
# v tibble  3.1.1     v dplyr   1.0.6
# v tidyr   1.1.3     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
# Warning message:
# "package 'tibble' was built under R version 3.6.3"Warning message:
# "package 'tidyr' was built under R version 3.6.3"Warning message:
# "package 'readr' was built under R version 3.6.3"Warning message:
# "package 'purrr' was built under R version 3.6.3"Warning message:
# "package 'dplyr' was built under R version 3.6.3"Warning message:
# "package 'stringr' was built under R version 3.6.3"Warning message:
# "package 'forcats' was built under R version 3.6.3"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
sd_x <- function (x){
  sqrt(sum((x-mean(x))^2/(length(x)-1)))
}

# %% [markdown]
# ## Question 2:  simulated dataset for healthy and diseased corals

# %%
coral_pop <- c("Montipora capitata",
              "Porites compressa",
              "Porites lobata")

coral_pop_sample<- sample(c("Montipora capitata",
                            "Porites compressa",
                            "Porites lobata"), 100, replace=TRUE)

health_statuts <- sample(c(TRUE,FALSE), 100, replace=TRUE, prob= c(0.8,0.2))
  
coral_health_df <- data.frame (coral_pop_sample, health_statuts)

coral_health_tbl = as_tibble(coral_health_df)
print(coral_health_df)
# Out:
#       coral_pop_sample health_statuts
# 1    Porites compressa          FALSE
# 2       Porites lobata           TRUE
# 3    Porites compressa          FALSE
# 4       Porites lobata           TRUE
# 5       Porites lobata           TRUE
# 6    Porites compressa           TRUE
# 7    Porites compressa           TRUE
# 8       Porites lobata           TRUE
# 9   Montipora capitata           TRUE
# 10  Montipora capitata           TRUE
# 11  Montipora capitata           TRUE
# 12      Porites lobata           TRUE
# 13  Montipora capitata           TRUE
# 14   Porites compressa           TRUE
# 15  Montipora capitata          FALSE
# 16   Porites compressa          FALSE
# 17  Montipora capitata          FALSE
# 18   Porites compressa           TRUE
# 19   Porites compressa           TRUE
# 20      Porites lobata          FALSE
# 21      Porites lobata           TRUE
# 22  Montipora capitata           TRUE
# 23      Porites lobata          FALSE
# 24      Porites lobata          FALSE
# 25  Montipora capitata           TRUE
# 26  Montipora capitata           TRUE
# 27  Montipora capitata           TRUE
# 28  Montipora capitata           TRUE
# 29   Porites compressa           TRUE
# 30      Porites lobata           TRUE
# 31  Montipora capitata           TRUE
# 32      Porites lobata           TRUE
# 33      Porites lobata           TRUE
# 34  Montipora capitata           TRUE
# 35      Porites lobata           TRUE
# 36   Porites compressa           TRUE
# 37      Porites lobata           TRUE
# 38      Porites lobata          FALSE
# 39      Porites lobata          FALSE
# 40      Porites lobata           TRUE
# 41   Porites compressa           TRUE
# 42   Porites compressa           TRUE
# 43  Montipora capitata          FALSE
# 44      Porites lobata           TRUE
# 45      Porites lobata           TRUE
# 46   Porites compressa           TRUE
# 47   Porites compressa           TRUE
# 48      Porites lobata           TRUE
# 49   Porites compressa           TRUE
# 50   Porites compressa           TRUE
# 51      Porites lobata           TRUE
# 52  Montipora capitata           TRUE
# 53      Porites lobata           TRUE
# 54   Porites compressa           TRUE
# 55      Porites lobata           TRUE
# 56      Porites lobata           TRUE
# 57  Montipora capitata           TRUE
# 58  Montipora capitata           TRUE
# 59  Montipora capitata           TRUE
# 60  Montipora capitata           TRUE
# 61      Porites lobata           TRUE
# 62  Montipora capitata          FALSE
# 63   Porites compressa           TRUE
# 64  Montipora capitata           TRUE
# 65  Montipora capitata           TRUE
# 66      Porites lobata           TRUE
# 67  Montipora capitata          FALSE
# 68      Porites lobata           TRUE
# 69  Montipora capitata          FALSE
# 70      Porites lobata           TRUE
# 71      Porites lobata           TRUE
# 72   Porites compressa           TRUE
# 73  Montipora capitata           TRUE
# 74  Montipora capitata           TRUE
# 75  Montipora capitata           TRUE
# 76   Porites compressa          FALSE
# 77   Porites compressa           TRUE
# 78   Porites compressa           TRUE
# 79  Montipora capitata           TRUE
# 80      Porites lobata           TRUE
# 81   Porites compressa          FALSE
# 82   Porites compressa          FALSE
# 83  Montipora capitata           TRUE
# 84   Porites compressa           TRUE
# 85  Montipora capitata           TRUE
# 86   Porites compressa           TRUE
# 87      Porites lobata           TRUE
# 88      Porites lobata           TRUE
# 89   Porites compressa           TRUE
# 90   Porites compressa           TRUE
# 91  Montipora capitata           TRUE
# 92  Montipora capitata           TRUE
# 93      Porites lobata           TRUE
# 94   Porites compressa           TRUE
# 95      Porites lobata           TRUE
# 96      Porites lobata           TRUE
# 97  Montipora capitata          FALSE
# 98      Porites lobata           TRUE
# 99  Montipora capitata           TRUE
# 100  Porites compressa           TRUE

# %% [markdown]
# ## Quesiton 3: Create a new column in coral_health_tbl called coral_cover
